# %%
import requests
import bs4
import time
import json
import re
import time

from gensim.parsing.preprocessing import remove_stopwords,strip_punctuation
import selenium.webdriver as webdriver
from selenium.common.exceptions import *

from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import ui
from selenium.webdriver.common.action_chains import ActionChains
from pprint import pprint

# %%
# import numpy as np

# import pandas as pd
# import tensorflow_hub as hub
# import tensorflow as tf

# class embedder:
#     def __init__(self, model, docs):
# #         model = "/home/ec2-user/GSE/"
#         self.embed = hub.Module(model)
#         print("load embeddings")
#         self.questions = docs

#         # with open('/home/ubuntu/opinions/moments.pkl', 'rb') as f:
#         #     self.questions = pkl.load(f)

#         # with open('response_dict.pkl', 'rb') as f:
#         #    self.response_dict = pkl.load(f)

#         embeddings = self.embed(self.questions)
#         sess = tf.Session()
#         sess.run(tf.global_variables_initializer())
#         sess.run(tf.tables_initializer())
#         self.q_embeddings = sess.run(embeddings)

#         print("two")
#         self.ss = tf.Session()
#         self.similarity_input_placeholder = tf.placeholder(tf.string, shape=(None))
#         self.similarity_message_encodings = self.embed(self.similarity_input_placeholder)
#         print("three")
#         self.ss.run(tf.tables_initializer())
#         print("four")
#         self.ss.run(tf.global_variables_initializer())

#     def retrieve_answer(self, text):
#         embedding = self.ss.run(
#             self.similarity_message_encodings, feed_dict={self.similarity_input_placeholder: [text]})[0]
#         sims = np.dot(embedding, self.q_embeddings.T)
#         index = np.argmax(sims)
#         # print(self.questions[index])
#         # response = self.response_dfict[self.questions[index]]
# #         response['confidence'] = 
# #         response['text'] = 
#         # return response
#         return self.questions[index], float(sims[index])

# %%
# traversed = set()
# def getControSpeechClass():
#     url = 'http://www.myspeechclass.com/controversial-speech-topics.html#popular'
#     crawl_url = requests.get(url, headers={'User-Agent': 'Mozilla/5.0'})
#     crawl_url.raise_for_status()
#     soup = bs4.BeautifulSoup(crawl_url.text, 'lxml')
#     sents = []
#     for item in soup.findAll('ol', {'class': 'ollist'}):
#         t = item.find_all('li')
#         for each in t:
#             sents.append(nlp_preprocess(each.text.lower()).strip())
#     return sents

# def recursiveSearch(links,driver):
#     global traversed
#     titles = []
#     for link in links:
#         if link in traversed:
#             continue
#         traversed.add(link)
#         if link == 'https://www.procon.org': continue
#         driver.get(link)
#         try:
#             t = driver.find_element_by_class_name('main-question')
#             titles.append(nlp_preprocess(t.text.lower()))
#             print(t.text)
#         except NoSuchElementException:
#             pass
#         text = driver.page_source
#         links = re.findall(r"https://[A-Za-z0-9\-_.]+\.procon\.org", text)
#         titles.extend(recursiveSearch(links,driver))
#     return titles
def download():
    pass

def getAirBnBImages():
    imageURLs = []
    #class="_13ky0r6y"
    #.<span class="_1m8bb6v">Price</span>
    #<span class="_pd52isb"><span class="_1m8bb6v">Price</span>$110</span>
    #<div class="_1df8dftk" role="img" aria-label="Times Square Luxury Place" style="width: 100%; height: 100%; background-image: url(&quot;https://a0.muscache.com/im/pictures/45636623/4c661e04_original.jpg?aki_policy=large&quot;);"></div>
    #<div class="_1df8dftk" role="img" aria-label="Times Square Luxury Place" style="width: 100%; height: 100%; background-image: url(&quot;https://a0.muscache.com/im/pictures/45636795/934ef3b5_original.jpg?aki_policy=large&quot;);"></div>
    #<button type="button" aria-label="Next image" class="_1pd3p1t8"><div class="_1us5tw2"><svg viewBox="0 0 18 18" role="img" aria-label="Next image" focusable="false" style="height: 24px; width: 24px; display: block; fill: rgb(255, 255, 255);"><path d="m4.29 1.71a1 1 0 1 1 1.42-1.41l8 8a1 1 0 0 1 0 1.41l-8 8a1 1 0 1 1 -1.42-1.41l7.29-7.29z" fill-rule="evenodd"></path></svg></div></button>
    #<button type="button" aria-label="Next image" class="_1pd3p1t8"><div class="_1us5tw2"><svg viewBox="0 0 18 18" role="img" aria-label="Next image" focusable="false" style="height: 24px; width: 24px; display: block; fill: rgb(255, 255, 255);"><path d="m4.29 1.71a1 1 0 1 1 1.42-1.41l8 8a1 1 0 0 1 0 1.41l-8 8a1 1 0 1 1 -1.42-1.41l7.29-7.29z" fill-rule="evenodd"></path></svg></div></button>
    #<div class="_8ssblpx"><div class="_gig1e7"><div itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><meta itemprop="name" content="Cozy Greenwich Village Abode - undefined - New York"><meta itemprop="position" content="5"><meta itemprop="url" content="www.airbnb.com/rooms/8682447?adults=2&amp;children=0&amp;infants=0&amp;guests=1"><div><div id="listing-8682447" class="_11ck647j"><div class="_hgs47m"><div class="_ni9axhe"><div class="_1u4mh4e"><div class="_i2484c"><button type="button" class="_1rp5252" id="8682447" aria-busy="false" style="padding: 8px; margin: -8px;"><svg viewBox="0 0 32 32" fill="#484848" fill-opacity="0.5" stroke="#ffffff" stroke-width="2.5" focusable="false" aria-label="Add listing to a list" role="img" stroke-linecap="round" stroke-linejoin="round" style="height: 28px; width: 28px; display: block; overflow: visible;"><path d="m23.99 2.75c-.3 0-.6.02-.9.05-1.14.13-2.29.51-3.41 1.14-1.23.68-2.41 1.62-3.69 2.94-1.28-1.32-2.46-2.25-3.69-2.94-1.12-.62-2.27-1-3.41-1.14a7.96 7.96 0 0 0 -.9-.05c-1.88 0-7.26 1.54-7.26 8.38 0 7.86 12.24 16.33 14.69 17.95a1 1 0 0 0 1.11 0c2.45-1.62 14.69-10.09 14.69-17.95 0-6.84-5.37-8.38-7.26-8.38"></path></svg></button></div><div aria-hidden="false" class="_e296pg"><div><div class="_13ky0r6y" style="padding-top: 66.6667%; background-color: rgb(216, 216, 216); background-position: initial initial; background-repeat: initial initial;"><div class="_1szwzht"><a href="/rooms/8682447?adults=2&amp;children=0&amp;infants=0&amp;guests=1" target="listing_8682447" aria-hidden="true" tabindex="-1"><span class="_1m8bb6v">Cozy Greenwich Village Abode</span><div class="_qptau"><div class="_yydl86"><div class="_1na7kj9b"><div class="_e296pg" style="width: 100%; height: 100%;"><div class="_1df8dftk" role="img" aria-label="Cozy Greenwich Village Abode" style="width: 100%; height: 100%; background-image: url(&quot;https://a0.muscache.com/im/pictures/e2586199-558d-46db-b8b8-98f0b1468dfb.jpg?aki_policy=large&quot;);"></div></div></div></div></div></a><div class="_17bbo57"><div class="_189umuy"><div class="_1x6fibgk" style="transform: scale(1); width: 18px; opacity: 1;"></div><div class="_1nyruiy" style="transform: scale(1); width: 16px; opacity: 1;"></div><div class="_1nyruiy" style="transform: scale(1); width: 16px; opacity: 1;"></div><div class="_1nyruiy" style="transform: scale(1); width: 16px; opacity: 1;"></div><div class="_1nyruiy" style="transform: scale(1); width: 16px; opacity: 1;"></div><div class="_1nyruiy" style="transform: scale(0.6666666666666666); width: 10.666666666666666px; opacity: 0.875;"></div></div></div><div class="_q2suj0z" aria-hidden="false"><div class="_tk908t"><button type="button" aria-label="Previous image" class="_6tgs86g"><div class="_1spvxxl"><svg viewBox="0 0 18 18" role="img" aria-label="Previous image" focusable="false" style="height: 24px; width: 24px; display: block; fill: rgb(255, 255, 255);"><path d="m13.7 16.29a1 1 0 1 1 -1.42 1.41l-8-8a1 1 0 0 1 0-1.41l8-8a1 1 0 1 1 1.42 1.41l-7.29 7.29z" fill-rule="evenodd"></path></svg></div></button><button type="button" aria-label="Next image" class="_q0jnehj"><div class="_1us5tw2"><svg viewBox="0 0 18 18" role="img" aria-label="Next image" focusable="false" style="height: 24px; width: 24px; display: block; fill: rgb(255, 255, 255);"><path d="m4.29 1.71a1 1 0 1 1 1.42-1.41l8 8a1 1 0 0 1 0 1.41l-8 8a1 1 0 1 1 -1.42-1.41l7.29-7.29z" fill-rule="evenodd"></path></svg></div></button></div></div></div></div></div></div></div></div><div class="_10ejfg4u"><div class="_1cjnzjo"><span class="_qlq27g"><a href="/rooms/8682447?adults=2&amp;children=0&amp;infants=0&amp;guests=1" target="listing_8682447" rel="noopener" data-check-info-section="true" class="_1ol0z3h"><div class="_1gifslso"><div style="margin-bottom: 4px;"><div class="_wuffzwa" style="color: rgb(87, 37, 51);"><div class="_1etkxf1" style="color: rgb(87, 37, 51);"><small class="_13dbiegr"><span style="color: rgb(87, 37, 51);">Entire apartment</span></small></div></div></div><div style="margin-bottom: 2px;"><div class="_1424jywo"><div class="_2izxxhr">Cozy Greenwich Village Abode</div></div></div><div class="_wlyu2v"><div class="_1nhodd4u"><div>3 guests<span aria-hidden="true"> · </span>1 bedroom<span aria-hidden="true"> · </span>2 beds<span aria-hidden="true"> · </span>1 bath</div></div></div><div style="margin-top: 2px;"><div class="_yupl54"><div class="_1nhodd4u">Wifi<span aria-hidden="true"> · </span>Kitchen<span aria-hidden="true"> · </span>Hair dryer<span aria-hidden="true"> · </span>Shampoo</div></div></div></div><div class="_1du2ssv0"></div><div class="_1ktspzq"><div><span><div><span><span class="_pd52isb"><span class="_1m8bb6v">Price</span>$165</span></span><span class="_1pjdsji"><span class="_1hh2h7tb">per night</span></span></div></span><div style="margin-top: 2px;"><div><span class="_q27mtmr"><span role="img" aria-label="Rating 4.5 out of 5"><span class="_z1pr8k6"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M971.5 379.5c9 28 2 50-20 67L725.4 618.6l87 280.1c11 39-18 75-54 75-12 0-23-4-33-12l-226.1-172-226.1 172.1c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L46.1 446.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7-23 28-39 52-39 25 0 47 17 54 41l87 276.1h280.1c23.2 0 44.2 16 52.2 40z"></path></svg></span><span class="_z1pr8k6"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M971.5 379.5c9 28 2 50-20 67L725.4 618.6l87 280.1c11 39-18 75-54 75-12 0-23-4-33-12l-226.1-172-226.1 172.1c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L46.1 446.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7-23 28-39 52-39 25 0 47 17 54 41l87 276.1h280.1c23.2 0 44.2 16 52.2 40z"></path></svg></span><span class="_z1pr8k6"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M971.5 379.5c9 28 2 50-20 67L725.4 618.6l87 280.1c11 39-18 75-54 75-12 0-23-4-33-12l-226.1-172-226.1 172.1c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L46.1 446.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7-23 28-39 52-39 25 0 47 17 54 41l87 276.1h280.1c23.2 0 44.2 16 52.2 40z"></path></svg></span><span class="_z1pr8k6"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M971.5 379.5c9 28 2 50-20 67L725.4 618.6l87 280.1c11 39-18 75-54 75-12 0-23-4-33-12l-226.1-172-226.1 172.1c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L46.1 446.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7-23 28-39 52-39 25 0 47 17 54 41l87 276.1h280.1c23.2 0 44.2 16 52.2 40z"></path></svg></span><span class="_5mvg07t"><span class="_15qz71s"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M971.5 379.5c9 28 2 50-20 67L725.4 618.6l87 280.1c11 39-18 75-54 75-12 0-23-4-33-12l-226.1-172-226.1 172.1c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L46.1 446.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7-23 28-39 52-39 25 0 47 17 54 41l87 276.1h280.1c23.2 0 44.2 16 52.2 40z"></path></svg></span><span class="_odm2ne"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M510.2 23.3l1 767.3-226.1 172.2c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L58 447.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7.1-23.1 28.1-39.1 52.1-39.1z"></path></svg></span></span></span></span><span class="_1m8bb6v">181 reviews</span><span class="_1gvnvab" aria-hidden="true"><span class="_p1g77r">181</span></span></div></div><div style="margin-top: 8px; margin-bottom: 8px;"><small class="_19dlebm7"><div>Free cancellation</div></small></div></div></div></a></span></div></div></div></div></div></div></div></div>
    url = 'https://www.airbnb.com/s/homes?adults=2&children=0&infants=0&guests=1&click_referer=t%3ASEE_ALL%7Csid%3A6a603b73-c735-487c-abe3-289ee89f00fc%7Cst%3AMAGAZINE_HOMES&query=new%20york%20city&room_types%5B%5D=Entire%20home%2Fapt&min_bedrooms=0&min_bathrooms=0&zoom=11&search_by_map=true&sw_lat=40.69591552825081&sw_lng=-74.14156490278883&ne_lat=40.80437003370684&ne_lng=-73.87420685981176&refinement_paths%5B%5D=%2Fhomes&allow_override%5B%5D=&s_tag=zMjDtyxP'
    driver= webdriver.Firefox()
    driver.get(url)
    text = driver.page_source
    #print(text)
    soup=bs4.BeautifulSoup(text)
    urlregex = re.compile(r"https:\/\/.*\.jpg")
    images=soup.find_all('div',  {"class": "_1df8dftk"})
    imageURLs = [[] for item in images]
#     print(imageURLs)
    pastImageURLs = None
    while (True):
        for ind, item in enumerate(images):
            t = str(item)
            m = re.search(urlregex, t)
            u = m.group(0)
            if u not in imageURLs[ind]:
                imageURLs[ind].append(u)

        if pastImageURLs == imageURLs:
            break
        pastImageURLs = imageURLs
    
        #python_button = ui.WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,"//button[@type='button' and @aria-label='Next image']")))
#         print(python_button[0])
#         python_button[0].click()
#         break
        #         print (python_button)
        print(driver)
        
#         element = driver.find_element_by_link_text(self.locator)
#         hov = ActionChains(driver).move_to_element("//button[@type='button' and @aria-label='Next image']").click()
#         hov.perform()


        break
        time(sleep)
        text = driver.page_source
        #print(text)
        soup=bs4.BeautifulSoup(text)
        urlregex = re.compile(r"https:\/\/.*\.jpg")
        images=soup.find_all('div',  {"class": "_1df8dftk"})
#         for button in python_button:
# #             test = python_button[0]
#             Hover = ActionChains(driver).move_to_element(button)
#             Hover.click().perform()
        
#             Actions hover=new Actions(driver);
#             hover.moveToElement(driver.findElement(By.xpath("id('background-experience')/div[1]/div/button[1]"))).perform();
#             driver.findElement(By.xpath("id('background-experience')/div[1]/div/button[1]")).click();
#             Thread.sleep(5000);
        
#         print(python_button[0])
#         python_button[0].click()
    pprint(imageURLs)
#     driver.close()
#     driver.quit()
    return None

def nlp_preprocess(sent):
    sent = strip_punctuation(sent)
    sent = remove_stopwords(sent)
    print(sent)
    return sent

def getWiki():
    with open('wiki.txt') as f:
        content = f.readlines()
        content = [nlp_preprocess(x.strip()) for x in content] 
    return content

def getTopics():
    with open('topics.txt') as f:
        content = f.readlines()
        content = [nlp_preprocess(x.strip()) for x in content] 
    return content

def getBlacklist():
    with open('blacklist.txt') as f:
        content = f.readlines()
        content = [x.strip() for x in content] 
    return content

# %%
t = getAirBnBImages()
# Out:
# <selenium.webdriver.firefox.webdriver.WebDriver (session="dda82212-7767-c946-a173-d6556a6973a8")>
# [['https://a0.muscache.com/im/pictures/45636623/4c661e04_original.jpg'],
#  ['https://a0.muscache.com/im/pictures/255bc11b-e3d8-44cc-973f-255ed6b34ae7.jpg'],
#  ['https://a0.muscache.com/im/pictures/7424636/83b49b54_original.jpg'],
#  ['https://a0.muscache.com/im/pictures/e2586199-558d-46db-b8b8-98f0b1468dfb.jpg'],
#  ['https://a0.muscache.com/im/pictures/ad37d7ec-4719-4b7e-a967-94f7e4bd262a.jpg'],
#  ['https://a0.muscache.com/im/pictures/b8bb6c36-26af-425b-a8fd-d2a9ca8e84be.jpg'],
#  ['https://a0.muscache.com/im/pictures/66285187/1973c1a5_original.jpg'],
#  ['https://a0.muscache.com/im/pictures/45639487/bba7496b_original.jpg'],
#  ['https://a0.muscache.com/im/pictures/0f1c0de7-558b-42bb-ad52-36de8d823e10.jpg'],
#  ['https://a0.muscache.com/im/pictures/84589ec2-8e81-4484-82cf-e0e546449a10.jpg'],
#  ['https://a0.muscache.com/im/pictures/29009262/eac3ac32_original.jpg'],
# ...

# %%
imageURLs = []
#class="_13ky0r6y"
#.<span class="_1m8bb6v">Price</span>
#<span class="_pd52isb"><span class="_1m8bb6v">Price</span>$110</span>
#<div class="_1df8dftk" role="img" aria-label="Times Square Luxury Place" style="width: 100%; height: 100%; background-image: url(&quot;https://a0.muscache.com/im/pictures/45636623/4c661e04_original.jpg?aki_policy=large&quot;);"></div>
#<div class="_1df8dftk" role="img" aria-label="Times Square Luxury Place" style="width: 100%; height: 100%; background-image: url(&quot;https://a0.muscache.com/im/pictures/45636795/934ef3b5_original.jpg?aki_policy=large&quot;);"></div>
#<button type="button" aria-label="Next image" class="_1pd3p1t8"><div class="_1us5tw2"><svg viewBox="0 0 18 18" role="img" aria-label="Next image" focusable="false" style="height: 24px; width: 24px; display: block; fill: rgb(255, 255, 255);"><path d="m4.29 1.71a1 1 0 1 1 1.42-1.41l8 8a1 1 0 0 1 0 1.41l-8 8a1 1 0 1 1 -1.42-1.41l7.29-7.29z" fill-rule="evenodd"></path></svg></div></button>
#<button type="button" aria-label="Next image" class="_1pd3p1t8"><div class="_1us5tw2"><svg viewBox="0 0 18 18" role="img" aria-label="Next image" focusable="false" style="height: 24px; width: 24px; display: block; fill: rgb(255, 255, 255);"><path d="m4.29 1.71a1 1 0 1 1 1.42-1.41l8 8a1 1 0 0 1 0 1.41l-8 8a1 1 0 1 1 -1.42-1.41l7.29-7.29z" fill-rule="evenodd"></path></svg></div></button>
#<div class="_8ssblpx"><div class="_gig1e7"><div itemprop="itemListElement" itemscope="" itemtype="http://schema.org/ListItem"><meta itemprop="name" content="Cozy Greenwich Village Abode - undefined - New York"><meta itemprop="position" content="5"><meta itemprop="url" content="www.airbnb.com/rooms/8682447?adults=2&amp;children=0&amp;infants=0&amp;guests=1"><div><div id="listing-8682447" class="_11ck647j"><div class="_hgs47m"><div class="_ni9axhe"><div class="_1u4mh4e"><div class="_i2484c"><button type="button" class="_1rp5252" id="8682447" aria-busy="false" style="padding: 8px; margin: -8px;"><svg viewBox="0 0 32 32" fill="#484848" fill-opacity="0.5" stroke="#ffffff" stroke-width="2.5" focusable="false" aria-label="Add listing to a list" role="img" stroke-linecap="round" stroke-linejoin="round" style="height: 28px; width: 28px; display: block; overflow: visible;"><path d="m23.99 2.75c-.3 0-.6.02-.9.05-1.14.13-2.29.51-3.41 1.14-1.23.68-2.41 1.62-3.69 2.94-1.28-1.32-2.46-2.25-3.69-2.94-1.12-.62-2.27-1-3.41-1.14a7.96 7.96 0 0 0 -.9-.05c-1.88 0-7.26 1.54-7.26 8.38 0 7.86 12.24 16.33 14.69 17.95a1 1 0 0 0 1.11 0c2.45-1.62 14.69-10.09 14.69-17.95 0-6.84-5.37-8.38-7.26-8.38"></path></svg></button></div><div aria-hidden="false" class="_e296pg"><div><div class="_13ky0r6y" style="padding-top: 66.6667%; background-color: rgb(216, 216, 216); background-position: initial initial; background-repeat: initial initial;"><div class="_1szwzht"><a href="/rooms/8682447?adults=2&amp;children=0&amp;infants=0&amp;guests=1" target="listing_8682447" aria-hidden="true" tabindex="-1"><span class="_1m8bb6v">Cozy Greenwich Village Abode</span><div class="_qptau"><div class="_yydl86"><div class="_1na7kj9b"><div class="_e296pg" style="width: 100%; height: 100%;"><div class="_1df8dftk" role="img" aria-label="Cozy Greenwich Village Abode" style="width: 100%; height: 100%; background-image: url(&quot;https://a0.muscache.com/im/pictures/e2586199-558d-46db-b8b8-98f0b1468dfb.jpg?aki_policy=large&quot;);"></div></div></div></div></div></a><div class="_17bbo57"><div class="_189umuy"><div class="_1x6fibgk" style="transform: scale(1); width: 18px; opacity: 1;"></div><div class="_1nyruiy" style="transform: scale(1); width: 16px; opacity: 1;"></div><div class="_1nyruiy" style="transform: scale(1); width: 16px; opacity: 1;"></div><div class="_1nyruiy" style="transform: scale(1); width: 16px; opacity: 1;"></div><div class="_1nyruiy" style="transform: scale(1); width: 16px; opacity: 1;"></div><div class="_1nyruiy" style="transform: scale(0.6666666666666666); width: 10.666666666666666px; opacity: 0.875;"></div></div></div><div class="_q2suj0z" aria-hidden="false"><div class="_tk908t"><button type="button" aria-label="Previous image" class="_6tgs86g"><div class="_1spvxxl"><svg viewBox="0 0 18 18" role="img" aria-label="Previous image" focusable="false" style="height: 24px; width: 24px; display: block; fill: rgb(255, 255, 255);"><path d="m13.7 16.29a1 1 0 1 1 -1.42 1.41l-8-8a1 1 0 0 1 0-1.41l8-8a1 1 0 1 1 1.42 1.41l-7.29 7.29z" fill-rule="evenodd"></path></svg></div></button><button type="button" aria-label="Next image" class="_q0jnehj"><div class="_1us5tw2"><svg viewBox="0 0 18 18" role="img" aria-label="Next image" focusable="false" style="height: 24px; width: 24px; display: block; fill: rgb(255, 255, 255);"><path d="m4.29 1.71a1 1 0 1 1 1.42-1.41l8 8a1 1 0 0 1 0 1.41l-8 8a1 1 0 1 1 -1.42-1.41l7.29-7.29z" fill-rule="evenodd"></path></svg></div></button></div></div></div></div></div></div></div></div><div class="_10ejfg4u"><div class="_1cjnzjo"><span class="_qlq27g"><a href="/rooms/8682447?adults=2&amp;children=0&amp;infants=0&amp;guests=1" target="listing_8682447" rel="noopener" data-check-info-section="true" class="_1ol0z3h"><div class="_1gifslso"><div style="margin-bottom: 4px;"><div class="_wuffzwa" style="color: rgb(87, 37, 51);"><div class="_1etkxf1" style="color: rgb(87, 37, 51);"><small class="_13dbiegr"><span style="color: rgb(87, 37, 51);">Entire apartment</span></small></div></div></div><div style="margin-bottom: 2px;"><div class="_1424jywo"><div class="_2izxxhr">Cozy Greenwich Village Abode</div></div></div><div class="_wlyu2v"><div class="_1nhodd4u"><div>3 guests<span aria-hidden="true"> · </span>1 bedroom<span aria-hidden="true"> · </span>2 beds<span aria-hidden="true"> · </span>1 bath</div></div></div><div style="margin-top: 2px;"><div class="_yupl54"><div class="_1nhodd4u">Wifi<span aria-hidden="true"> · </span>Kitchen<span aria-hidden="true"> · </span>Hair dryer<span aria-hidden="true"> · </span>Shampoo</div></div></div></div><div class="_1du2ssv0"></div><div class="_1ktspzq"><div><span><div><span><span class="_pd52isb"><span class="_1m8bb6v">Price</span>$165</span></span><span class="_1pjdsji"><span class="_1hh2h7tb">per night</span></span></div></span><div style="margin-top: 2px;"><div><span class="_q27mtmr"><span role="img" aria-label="Rating 4.5 out of 5"><span class="_z1pr8k6"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M971.5 379.5c9 28 2 50-20 67L725.4 618.6l87 280.1c11 39-18 75-54 75-12 0-23-4-33-12l-226.1-172-226.1 172.1c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L46.1 446.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7-23 28-39 52-39 25 0 47 17 54 41l87 276.1h280.1c23.2 0 44.2 16 52.2 40z"></path></svg></span><span class="_z1pr8k6"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M971.5 379.5c9 28 2 50-20 67L725.4 618.6l87 280.1c11 39-18 75-54 75-12 0-23-4-33-12l-226.1-172-226.1 172.1c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L46.1 446.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7-23 28-39 52-39 25 0 47 17 54 41l87 276.1h280.1c23.2 0 44.2 16 52.2 40z"></path></svg></span><span class="_z1pr8k6"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M971.5 379.5c9 28 2 50-20 67L725.4 618.6l87 280.1c11 39-18 75-54 75-12 0-23-4-33-12l-226.1-172-226.1 172.1c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L46.1 446.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7-23 28-39 52-39 25 0 47 17 54 41l87 276.1h280.1c23.2 0 44.2 16 52.2 40z"></path></svg></span><span class="_z1pr8k6"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M971.5 379.5c9 28 2 50-20 67L725.4 618.6l87 280.1c11 39-18 75-54 75-12 0-23-4-33-12l-226.1-172-226.1 172.1c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L46.1 446.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7-23 28-39 52-39 25 0 47 17 54 41l87 276.1h280.1c23.2 0 44.2 16 52.2 40z"></path></svg></span><span class="_5mvg07t"><span class="_15qz71s"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M971.5 379.5c9 28 2 50-20 67L725.4 618.6l87 280.1c11 39-18 75-54 75-12 0-23-4-33-12l-226.1-172-226.1 172.1c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L46.1 446.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7-23 28-39 52-39 25 0 47 17 54 41l87 276.1h280.1c23.2 0 44.2 16 52.2 40z"></path></svg></span><span class="_odm2ne"><svg viewBox="0 0 1000 1000" role="presentation" aria-hidden="true" focusable="false" style="height: 1em; width: 1em; display: block; fill: currentcolor;"><path d="M510.2 23.3l1 767.3-226.1 172.2c-25 17-59 12-78-12-12-16-15-33-8-51l86-278.1L58 447.5c-21-17-28-39-19-67 8-24 29-40 52-40h280.1l87-278.1c7.1-23.1 28.1-39.1 52.1-39.1z"></path></svg></span></span></span></span><span class="_1m8bb6v">181 reviews</span><span class="_1gvnvab" aria-hidden="true"><span class="_p1g77r">181</span></span></div></div><div style="margin-top: 8px; margin-bottom: 8px;"><small class="_19dlebm7"><div>Free cancellation</div></small></div></div></div></a></span></div></div></div></div></div></div></div></div>
url = 'https://www.airbnb.com/s/homes?adults=2&children=0&infants=0&guests=1&click_referer=t%3ASEE_ALL%7Csid%3A6a603b73-c735-487c-abe3-289ee89f00fc%7Cst%3AMAGAZINE_HOMES&query=new%20york%20city&room_types%5B%5D=Entire%20home%2Fapt&min_bedrooms=0&min_bathrooms=0&zoom=11&search_by_map=true&sw_lat=40.69591552825081&sw_lng=-74.14156490278883&ne_lat=40.80437003370684&ne_lng=-73.87420685981176&refinement_paths%5B%5D=%2Fhomes&allow_override%5B%5D=&s_tag=zMjDtyxP'
driver= webdriver.Chrome("/usr/local/bin/chromedriver")
time.sleep(3)
driver.get(url)
text = driver.page_source
#print(text)
soup=bs4.BeautifulSoup(text)
urlregex = re.compile(r"https:\/\/.*\.jpg")
images=soup.find_all('div',  {"class": "_1df8dftk"})
imageURLs = [[] for item in images]
#     print(imageURLs)
pastImageURLs = []

all_image_urls = {}
imgNum = 1
while (True):
#     text = driver.getPageSource();
#     soup=bs4.BeautifulSoup(text)
#     images=soup.find_all('div',  {"class": "_1df8dftk"})
    NoChanges = True
    for ind, item in enumerate(images):
        t = str(item)
        m = re.search(urlregex, t)
        u = m.group(0)
#         if u not in imageURLs[ind]:
        if u not in all_image_urls:
            all_image_urls[u] = imgNum
            imgNum+=1
#             imageURLs[ind].append(u)
            NoChanges = False
    print(len(all_image_urls))
    print(all_image_urls)
    if NoChanges:
#         print(pastImageURLs)
        #print(len(imageURLs))
        break
    pastImageURLs = imageURLs[:]
    print(len(imageURLs[0]))
    #rotate imges
#     find_elements_by_xpath("//a[@class='primary-button']")
#     shoesize = ui.WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//div[@class='_14csrlku']")))
#     shoesize.click()
    elements = driver.find_elements_by_xpath("//div[@class='_8ssblpx']")
    if not elements:
        elements = driver.find_elements_by_xpath("//div[@class='_1wcpzyga']")
    if not elements:
        elements = driver.find_elements_by_xpath("//div[@class='_1lh7ha0a']")
        
        
    nexts = driver.find_elements_by_xpath("//button[@type='button' and @aria-label='Next image']")
    for en, el in enumerate(elements):
        t = 1
        while (True):
            try:
                hov = ActionChains(driver).move_to_element(el).perform()
                time.sleep(t)
                #WebDriverWait(driver, 3).until(EC.presence_of_element_located( nexts[en]))
                nexts[en].click()
                time.sleep(t)
                if t > 5: 
                    print("TIME ERROR")
                    break
            except Exception:
                t+=1
                continue
            break
            
#         hov = ActionChains(driver).move_to_element(el).perform()
#         time.sleep(2)
#         #WebDriverWait(driver, 3).until(EC.presence_of_element_located( nexts[en]))
#         nexts[en].click()
#         time.sleep(2)
#         pass
    
    #get page source again
    text = driver.page_source
    soup=bs4.BeautifulSoup(text)
    images=soup.find_all('div',  {"class": "_1df8dftk"})
    continue
    
    
    
    
    
    break
    element.click()
    div_element = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, "//div[@class='_8ssblpx']")))
    hover = ActionChains(driver).move_to_element(div_element)
    hover.perform()

    button = WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, "//button[@type='button' and @aria-label='Next image']")))
    hover = ActionChains(driver).move_to_element(button)
    hover.perform()

    button.click()
    break
    
#     div._14csrlku:nth-child(1)
    element = driver.find_element_by_xpath("//button[@type='button' and @aria-label='Next image']")
#     driver.move_to_element().perform()
    shoesize = ui.WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.XPATH, "//button[@type='button' and @aria-label='Next image']")))
    shoesize.click()
    #browser.find_element_by_xpath("//*[@id='pdp_addtocart_button']").click()
    break
    print(len(element))
    for item in element:
        item.click()
#         hov.move_to_element(item).click().perform()
#         time.sleep(3)
#         hov.click()
#         time.sleep(3)
        #print(item)
    break
    
    #python_button = ui.WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,"//button[@type='button' and @aria-label='Next image']")))
#         print(python_button[0])
#         python_button[0].click()
#         break
    #         print (python_button)
    print(driver)

#         element = driver.find_element_by_link_text(self.locator)
#         hov = ActionChains(driver).move_to_element("//button[@type='button' and @aria-label='Next image']").click()
#         hov.perform()

    #<div aria-hidden="false" class="_1ui5bsf3"><div class="_1hgpf80k" style="background-col
#     action = ActionChains(driver);
#     element = driver.find_element_by_xpath("//button[@type='button' and @aria-label='Next image']")
    
    print(element)
    break
#     action.move_to_element(outside).perform()
#     action.move_to_element(element).perform()
#     \hov = ActionChains(driver).move_to_element(outside).perform()
#     hov = ui.WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH,"//button[@type='button' and @aria-label='Next image']"))).click()
#     time.sleep(2)
#     hov.click()
                            

    
    break
    time(sleep)
    text = driver.page_source
    #print(text)
    soup=bs4.BeautifulSoup(text)
    urlregex = re.compile(r"https:\/\/.*\.jpg")
    images=soup.find_all('div',  {"class": "_1df8dftk"})
#         for button in python_button:
# #             test = python_button[0]
#             Hover = ActionChains(driver).move_to_element(button)
#             Hover.click().perform()

#             Actions hover=new Actions(driver);
#             hover.moveToElement(driver.findElement(By.xpath("id('background-experience')/div[1]/div/button[1]"))).perform();
#             driver.findElement(By.xpath("id('background-experience')/div[1]/div/button[1]")).click();
#             Thread.sleep(5000);

#         print(python_button[0])
#         python_button[0].click()
pprint(imageURLs)
# Out:
# /anaconda3/lib/python3.6/site-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /anaconda3/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# 18
# ...

# %%
# sents2 = []
# for question in questions:
#     sents2.append(question))
# print(sents2)

# %%
#all = wikitopics + sents + questions
all = questions

# %%
from pprint import pprint 
pprint(all)
# Out:
# ['2003 invasion Iraq',
#  'Abortion',
#  'Affirmative action',
#  'African National Congress',
#  'Alberta secessionism',
#  'American Civil Liberties Union ACLU',
#  'American Hunters Shooters Association',
#  'History Jews United States historical review American Jews',
#  'Anarchism',
#  'Anarcho capitalism',
#  'Anti Americanism',
#  'Anti clericalism',
#  'Anti Irish racism',
#  'Antisemitism',
#  'Asian American',
#  'Atheism',
#  'Austrian School',
#  'Bashar Assad Syrian civil war',
#  'Black Lives Matter',
#  'Black supremacy',
#  'Boricua Popular Army – known Los Macheteros',
#  'British National Party',
#  'Capitalism',
#  'Capital punishment',
#  'Catalonia',
#  'Cherokee Americans – Cherokee ancestry',
#  'Chinese spies',
#  'Christian right known religious right',
#  'CIA leak scandal aka Plame affair controversies include naming articles',
#  'CIA leak scandal timeline aka Plame affair timeline controversies include '
#  'naming articles',
#  'Communism',
# ...

# %%
topics = getTopics()
blacklist = getBlacklist()
print(len(blacklist))
regex = genRegex(blacklist)
# Out:
# 2003 invasion Iraq
# Abortion
# Affirmative action
# African National Congress
# Alberta secessionism
# American Civil Liberties Union ACLU
# American Hunters Shooters Association
# History Jews United States historical review American Jews
# Anarchism
# Anarcho capitalism
# Anti Americanism
# Anti clericalism
# Anti Irish racism
# Antisemitism
# Asian American
# Atheism
# Austrian School
# Bashar Assad Syrian civil war
# Black Lives Matter
# Black supremacy
# Boricua Popular Army – known Los Macheteros
# British National Party
# Capitalism
# Capital punishment
# Catalonia
# Cherokee Americans – Cherokee ancestry
# Chinese spies
# Christian right known religious right
# Plame Affair
# Communism
# Communist government
# Communist state
# Conservatism United States
# Controversy
# Copyright Free software viral license Copyright infringement software DMCA
# copyright term extension Inducement Child Exploitation
# Corsica – separatism activity
# Crime United States
# Criticism Walmart
# ...

# %%
ed = embedder('./GSE/',topics)

# %%
# text, confidence = ed.retrieve_answer("world trade center")
# print(confidence)
print(contro(regex, ed, "Michael Cohen Secretly Taped Trump Discussing Payment to Playboy Model"))
# Out:
# False

# %%
import csv
controsents = loadControTest()
# print((controsents))
with open('text.csv', newline='') as csvfile:
    text = csv.reader(csvfile)
    i = 0
    for row in text:
        
        if not row: 
            continue
        else:
            sentence = row[0]
            if not sentence:
                continue
                
        val = contro(regex, ed, sentence)
        
        if val and sentence not in controsents:
            print(sentence)
#         text, confidence = ed.retrieve_answer(sentence)
#         print("{0} | {1} | {2}".format(sentence, text, confidence))
        #print("{0} | {1}".format(sentence, val))
        if i == 2000: break
#         if confidence > .8:
#             print("{0} | {1} | {2}".format(sentence, text, confidence))
        i+=1
# Out:
# no not really
# are you
# that again
# very
# really
# off
# red dead redemption
# no what
# murder mystery
# that's stupid
# hell no
# her
# do you
# i would
# yeah because you're a fucking a. i. bitch
# five is i said sharks dumb ass stupid
# bill
# ha ha that that
# xxx italian
# ask her about trump
# your face
# your face
# do you have anything
# where kylo ren and rey kill the emperor
# no no
# you're an idiot
# dead how it said
# fuck off
# oh that's the main character as me and i probably get murdered at the end cause it's a very sketchy place
# myself
# canada
#  it
# i have a name
# what about it
# what do you think about death
# no you're a loser
# what is that
# did you get up
# and
# snow crash
# myself
# you are
# no when
# i think it's stupid
# dizicks
# can you stop talking about donald trump
# my call
# artificial intelligence
# artificial intelligence
# springtime for hitler
# god
# ...
